# %% [markdown]
# ## Question 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pipenv version is 2024.2.0

# %% [markdown]
# ## Question 2

# %% [markdown]
# #pipenv install scikit-learn==1.5.2 #in terminal

# %% [markdown]
# The first hash of scikit-learn in Pipfile.lock is :
# "sha256:03b6158efa3faaf1feea3faa884c840ebd61b6484167c711548fce208ea09445"

# %% [markdown]
# ## Question 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# file is code/predict.py

import pickle
import os

dv_file = "dv.bin"

with open(dv_file,"rb") as file:
    dv = pickle.load(file)

model_file = "model1.bin"

with open(model_file,"rb") as file:
    model = pickle.load(file)

customer = {
    "job": "management", 
    "duration": 400, 
    "poutcome": "success"
}

X = dv.transform([customer])
print(model.predict_proba(X)[0,1])

# %% [markdown]
# Prediction propability is : 0.759

# %% [markdown]
# ## Question 4

# %% [markdown]
# Flask app in code/serving_churn.py <br>
# Posting to the Flask app in code/test_app.py <br>
#
# I runned the flask app with pipenv

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# the probability that this client will get a subscription is 0.335

# %% [markdown]
# ## Question 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Image size is 130 MB

# %% [markdown]
# ## Question 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The correct answer is 0.757.
